# %%
import re
import regex

import locale
import calendar
import datetime

import pandas as pd
from collections import Counter

import emoji
import enchant
import probablepeople as pp
from wordcloud import WordCloud
from stop_words import get_stop_words

import plotly.io as pio
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, download_plotlyjs, plot, iplot
import matplotlib.pyplot as plt

import sys
import itertools 
import numpy as np
from math import log
from itertools import tee
from operator import itemgetter
from collections import defaultdict

# %%
# Global Settings
color_tere = "#33b2cb"
color_tere_dark = "#237C8E"

color_vivi = "#db70c9"
color_vivi_dark = '#994e8c'

yellow = 'rgb(255,191,0)'
dark_yellow = 'rgb(179,134,0)'

pio.templates.default = "none"
locale.setlocale(locale.LC_ALL, 'es_ES')
d = enchant.Dict("es_ES")
d2 = enchant.Dict("en_US")

# %% [markdown]
# # Load data

# %%
with open("ChatTere.txt") as file:  
    data = file.readlines()

# %%
df = []
date_pattern = "\[(.*?)\]"

for message in data:
    try:
        message_dict = {
            'datetime': re.search(date_pattern, message).group()[1:-1],
            'user': message.split()[3],
            'text': message.split(maxsplit=5)[-1]
        }
        if "This message was deleted." not in message_dict['text']: # Lo que se borra se olvida
            df.append(message_dict)
    except:
        # Whatsapp a veces no lee muy bien los mensajes con saltos de linea
        if message.strip() != "":
            df[-1]['text'] = f"{df[-1]['text']}{message}"

# %% [markdown]
# # Transform data

# %%
df = pd.DataFrame(df)

df['datetime'] = pd.to_datetime(df['datetime'], infer_datetime_format=True)

def quick_classification(text):
    if "audio omitted" in text:
        return "Audio"
    if any(file_type in text for file_type in ['image omitted', "video omitted"]):
        return "Image/Video"
    if any(file_type in text for file_type in ['GIF omitted', "sticker omitted"]):
        return "Sticker/GIF"
    if "document omitted" in text: 
        return "Document"
    if "Contact card omitted" in text: 
        return "Contact"
    if set(text.strip().lower()) == {'a', 'j'}:
        return "RISA" # Nos reimos tanto que tocó incluir una categoria para esto
    return "Text"

df['type'] = df['text'].apply(lambda text: quick_classification(text))

df['text'] = df['text'].apply(lambda text: text.strip())

# %%
df
# Out:
#                  datetime     user  \
# 0     2019-02-20 21:51:37   Teresa
# 1     2019-02-20 21:51:37  Viviana
# 2     2019-02-20 21:51:50   Teresa
# 3     2019-02-20 21:52:27   Teresa
# 4     2019-02-20 21:52:33  Viviana
# ...                   ...      ...
# 15980 2020-04-25 12:03:46  Viviana
# 15981 2020-04-27 21:58:16   Teresa
# 15982 2020-04-27 22:15:44  Viviana
# 15983 2020-04-27 22:16:01  Viviana
# 15984 2020-04-27 22:17:17   Teresa
#
#                                                     text  type
# 0      ‎Messages to this chat and calls are now secur...  Text
# 1                            Pariente de Bartolomé Calvo  Text
# 2                                              Lo logré!  Text
# 3                          Soy una crack, caiste primero  Text
# 4      (Paréntesis: Si es Bartolomé? Espero no haberm...  Text
# ...                                                  ...   ...
# 15980                                          Jajajajaj  RISA
# 15981  El miedo al contagio se apoderó de las calles ...  Text
# 15982                       Amiga hoy te estaba pensando  Text
# 15983                          Como están tú y Marcelle?  Text
# 15984                                         Bien amiga  Text
#
# [15985 rows x 4 columns]

# %% [markdown]
# # Exploración Inicial

# %%
print(f"Primer fecha: {df['datetime'].min()}")
print(f"Última fecha: {df['datetime'].max()}\n")

print(f"Tiempo transcurrido: {(df['datetime'].max() - df['datetime'].min()).days}")
print(f"Número de días en que hablamos: {df['datetime'].apply(lambda date: date.date()).nunique()}")

print(f"Hablamos {round(df['datetime'].apply(lambda date: date.date()).nunique()/(df['datetime'].max() - df['datetime'].min()).days*100,2)}% de los días.")
# Out:
# Primer fecha: 2019-02-20 21:51:37
# Última fecha: 2020-04-27 22:17:17
#
# Tiempo transcurrido: 432
# Número de días en que hablamos: 274
# Hablamos 63.43% de los días.

# %%
print(f"Número de mensajes: {df.shape[0]:,}")
print(f"Promedio de mensajes por día cuando hablamos: {df.shape[0]/df['datetime'].apply(lambda date: date.date()).nunique():.1f}")
# Out:
# Número de mensajes: 15,985
# Promedio de mensajes por día cuando hablamos: 58.3

# %%
print("Tipo de mensajes:")
df['type'].value_counts()
# Out:
# Tipo de mensajes:
# Text           12287
# Audio           1516
# RISA             989
# Image/Video      809
# Sticker/GIF      377
# Document           4
# Contact            3
# Name: type, dtype: int64

# %% [markdown]
# # Risas

# %%
df[df['type']=='RISA'].text.value_counts()[:20]
# Out:
# Jajajaja                  128
# Jajajajaja                109
# Jajaja                     82
# Jajajajajaja               82
# Jajajajajajaja             43
# Jajajajajajajaja           37
# JAJAJAJAJAJA               30
# JAJAJAJAJAJAJA             30
# Jajajajajajajajaja         23
# JAJAJAJA                   21
# JAJAJAJAJAJAJAJA           21
# JAJAJAJAJA                 20
# Jajajajajajajajajaja       18
# Jajajaj                    15
# Jajajajajajajajajajaja     14
# JAJAJAJAJAJAJAJAJA         13
# Jajajajaj                  12
# JAJAJAJAJAJAJAJAJAJAJA     12
# jajaja                     11
# JAJAJAJAJAJAJAJAJAJA       10
# Name: text, dtype: int64

# %%
print("Tamaño de la risa más corta:")
df[df['type']=='RISA'].text.str.len().min()
# Out:
# Tamaño de la risa más corta:
# 4

# %%
print("Cómo es la risa más corta:")
temp = df[df['type']=='RISA'].text.str.len().reset_index()
index_risa_larga = temp[temp['text']==temp['text'].min()]['index'].values[0]

df[df['type']=='RISA'].loc[index_risa_larga]
# Out:
# Cómo es la risa más corta:
# datetime    2019-04-08 14:51:58
# user                     Teresa
# text                       Jajj
# type                       RISA
# Name: 2216, dtype: object

# %%
print("Tamaño de la risa más larga:")
df[df['type']=='RISA'].text.str.len().max()
# Out:
# Tamaño de la risa más larga:
# 1950

# %%
print("Cómo es la risa más larga:")
temp = df[df['type']=='RISA'].text.str.len().reset_index()
index_risa_larga = temp[temp['text']==temp['text'].max()]['index'].values[0]

print(df[df['type']=='RISA'].loc[index_risa_larga])

print(df[df['type']=='RISA'].loc[index_risa_larga]['text'])
# Out:
# Cómo es la risa más larga:
# datetime                                  2019-02-26 15:56:19
# user                                                   Teresa
# text        JAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJA...
# type                                                     RISA
# Name: 140, dtype: object
# ...

# %%
temp = df[df['type']=='RISA'].text.str.len().reset_index()
temp.columns = ['loc', 'laugh_length']
buckets = [0, 6, 25, 50, 100, 200, 2000]
buckets_labels = ['"Jajaja"<br>Menos de 6 car.', '(6,25]', '(25,50]', '(50,100]', '(100,200]', 'Más de 200<br>caracteres']
temp = pd.cut(temp['laugh_length'], bins=buckets, labels=buckets_labels)
temp = temp.reset_index()['laugh_length'].value_counts().reset_index()
temp.columns = ['laugh_length', 'count_laughs']

# %%
trace = go.Bar(
                x=temp.laugh_length.values,
                y=temp.count_laughs.values,
                text=[f"{count} mensajes" for (lenght,count) in zip(temp.laugh_length.values, temp.count_laughs.values)],
                hoverinfo='text', 
                opacity=0.6,
                marker=dict(color=yellow,
                            line=dict(color=dark_yellow,width=1.5,)
                           ),
                width=.8)

layout = go.Layout(title='¿Qué tan largas son nuestras risas?',
                   xaxis=dict(title='Número de caracteres', 
                              categoryorder='array',
                              categoryarray=buckets_labels),
                   yaxis=dict(title='Número de mensajes'),
                   #width = 900, height=400
                  )

fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="d9c82a20-d187-4c57-ba29-82847ff78421" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d9c82a20-d187-4c57-ba29-82847ff78421")) {
#                     Plotly.newPlot(
#                         'd9c82a20-d187-4c57-ba29-82847ff78421',
#                         [{"hoverinfo": "text", "marker": {"color": "rgb(255,191,0)", "line": {"color": "rgb(179,134,0)", "width": 1.5}}, "opacity": 0.6, "text": ["805 mensajes", "117 mensajes", "49 mensajes", "14 mensajes", "3 mensajes", "1 mensajes"], "type": "bar", "width": 0.8, "x": ["(6,25]", "\"Jajaja\"<br>Menos de 6 car.", "(25,50]", "(50,100]", "(100,200]", "M\u00e1s de 200<br>caracteres"], "y": [805, 117, 49, 14, 3, 1]}],
#                         {"template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "\u00bfQu\u00e9 tan largas son nuestras risas?"}, "xaxis": {"categoryarray": ["\"Jajaja\"<br>Menos de 6 car.", "(6,25]", "(25,50]", "(50,100]", "(100,200]", "M\u00e1s de 200<br>caracteres"], "categoryorder": "array", "title": {"text": "N\u00famero de caracteres"}}, "yaxis": {"title": {"text": "N\u00famero de mensajes"}}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d9c82a20-d187-4c57-ba29-82847ff78421');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
pio.write_html(fig, file='Plot1.html', auto_open=True)

# %%
temp = df[df['type']=='RISA'][['datetime','user', 'text']]
temp['datetime'] = temp['datetime'].apply(lambda date: date.date())
temp['laugh_length'] = list(df[df['type']=='RISA'].text.str.len().values)
temp['color'] = [color_tere if color=='Teresa' else color_vivi for color in temp.user.values]
temp = temp[temp['laugh_length']<1950] # Quitar la risa más larga porque arruina todos los cálculos
temp
# Out:
#          datetime     user                  text  laugh_length    color
# 20     2019-02-26   Teresa          Jajajajajaja            12  #33b2cb
# 34     2019-02-26  Viviana              Jajajaja             8  #db70c9
# 71     2019-02-26  Viviana                Jajaja             6  #db70c9
# 76     2019-02-26   Teresa                jajaja             6  #33b2cb
# 78     2019-02-26  Viviana          Jajajajajaja            12  #db70c9
# ...           ...      ...                   ...           ...      ...
# 15883  2020-04-12   Teresa  JAJAJAJAJAJAJAJAJAJA            20  #33b2cb
# 15884  2020-04-12  Viviana           Jajajajajaj            11  #db70c9
# 15890  2020-04-12  Viviana            Jajajajaja            10  #db70c9
# 15899  2020-04-12   Teresa          Jajajajajaja            12  #33b2cb
# 15980  2020-04-25  Viviana             Jajajajaj             9  #db70c9
#
# [988 rows x 5 columns]

# %%
trace_tere = go.Box(
                y=temp[temp['user']=='Teresa'].laugh_length.values,
                boxpoints='all',
                pointpos = 0,
                jitter=1,
                text=[f"{laugh}<br>Tamaño: {lenght}<br>{date}" for laugh, lenght, date
                      in zip(temp[temp['user']=='Teresa'].text,
                             temp[temp['user']=='Teresa'].laugh_length,
                             temp[temp['user']=='Teresa'].datetime)],
                hoverinfo = 'text',
                marker = dict(color = color_tere),
                line = dict(color = 'rgba(0,0,0,0)'),
                fillcolor = 'rgba(0,0,0,0)',
                name='Teresa'
               )

trace_vivi = go.Box(
                y=temp[temp['user']=='Viviana'].laugh_length.values,
                boxpoints='all', 
                pointpos = 0,
                jitter=1,
                text=[f"{laugh}<br>Tamaño: {lenght}<br>{date}" for laugh, lenght, date
                      in zip(temp[temp['user']=='Viviana'].text,
                             temp[temp['user']=='Viviana'].laugh_length,
                             temp[temp['user']=='Viviana'].datetime)],
                hoverinfo='text',
                marker = dict(color = color_vivi),
                line = dict(color = 'rgba(0,0,0,0)'),
                fillcolor = 'rgba(0,0,0,0)',
                name='Viviana'
               )

layout = go.Layout(title='¿Qué tan largas son nuestras risas?',
                   yaxis=dict(title='Tamaño de la risa')
                  )

fig = go.Figure(data=[trace_tere, trace_vivi], layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="f6fb406f-c8e0-47d3-a3e8-c6c08b4aa8da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f6fb406f-c8e0-47d3-a3e8-c6c08b4aa8da")) {
#                     Plotly.newPlot(
#                         'f6fb406f-c8e0-47d3-a3e8-c6c08b4aa8da',
#                         [{"boxpoints": "all", "fillcolor": "rgba(0,0,0,0)", "hoverinfo": "text", "jitter": 1, "line": {"color": "rgba(0,0,0,0)"}, "marker": {"color": "#33b2cb"}, "name": "Teresa", "pointpos": 0, "text": ["Jajajajajaja<br>Tama\u00f1o: 12<br>2019-02-26", "jajaja<br>Tama\u00f1o: 6<br>2019-02-26", "JAJAJAJAJAJAJAJAJAJAJAJAJA<br>Tama\u00f1o: 26<br>2019-02-26", "JAJAJAJAJAJAJAJAJAJAJA<br>Tama\u00f1o: 22<br>2019-02-26", "Jajajaja<br>Tama\u00f1o: 8<br>2019-02-26", "JAJAJAJAJAJAJAJAJAJAJAJAJA<br>Tama\u00f1o: 26<br>2019-02-26", "Jajajajajajaja<br>Tama\u00f1o: 14<br>2019-02-26", "Jajajajaja<br>Tama\u00f1o: 10<br>2019-03-04", "Jajajajajajaja<br>Tama\u00f1o: 14<br>2019-03-06", "Jajajajajaja<br>Tama\u00f1o: 12<br>2019-03-06", "Jajaja<br>Tama\u00f1o: 6<br>2019-03-06", "Jajajajajaja<br>Tama\u00f1o: 12<br>2019-03-06", "Jajajajajajaja<br>Tama\u00f1o: 14<br>2019-03-06", "jajajajajajaj<br>Tama\u00f1o: 13<br>2019-03-08", "jajaja<br>Tama\u00f1o: 6<br>2019-03-08", "JAJAJAJAJAJAJAJAJAJA<br>Tama\u00f1o: 20<br>2019-03-08", "JAJAJAJAJAJ<br>Tama\u00f1o: 11<br>2019-03-08", "jajajajajajjaja<br>Tama\u00f1o: 15<br>2019-03-08", "JAJAJAJAJAJAJAJAJA<br>Tama\u00f1o: 18<br>2019-03-08", "JAJAJAJJAJA<br>Tama\u00f1o: 11<br>2019-03-08", "jajajaja<br>Tama\u00f1o: 8<br>2019-03-08", "JAJAJAJAJAJAJAJAJAJAJA<br>Tama\u00f1o: 22<br>2019-03-08", "Jajajajajajajajajaja<br>Tama\u00f1o: 20<br>2019-03-09", "Jajajajajajajjajajajaja<br>Tama\u00f1o: 23<br>2019-03-09", "Jajajaja<br>Tama\u00f1o: 8<br>2019-03-09", "JAJAJAJAJAJJAJAJAJAJA<br>Tama\u00f1o: 21<br>2019-03-09", "JAJAJAJAJAJAJAJAJA<br>Tama\u00f1o: 18<br>2019-03-09", "Jajajajajajajajaja<br>Tama\u00f1o: 18<br>2019-03-09", "Jajajajaja<br>Tama\u00f1o: 10<br>2019-03-10", "Jajajajaja<br>Tama\u00f1o: 10<br>2019-03-10", "Jajaja<br>Tama\u00f1o: 6<br>2019-03-15", "Jajajajaja<br>Tama\u00f1o: 10<br>2019-03-18", "Jajaja<br>Tama\u00f1o: 6<br>2019-03-18", "Jajaja<br>Tama\u00f1o: 6<br>2019-03-18", "Jajaja<br>Tama\u00f1o: 6<br>2019-03-18", "jajajajajjajajajajjaaja<br>Tama\u00f1o: 23<br>2019-03-19", "Jajajaja<br>Tama\u00f1o: 8<br>2019-03-19", "Jajajajajaja<br>Tama\u00f1o: 12<br>2019-03-19", "Jajaja<br>Tama\u00f1o: 6<br>2019-03-30", "Jajaja<br>Tama\u00f1o: 6<br>2019-03-30", "Jajajaja<br>Tama\u00f1o: 8<br>2019-03-30", "Jajajajajaj<br>Tama\u00f1o: 11<br>2019-04-02", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-02", "JAJAJAJAJAJA<br>Tama\u00f1o: 12<br>2019-04-02", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-02", "Jajajajajajaja<br>Tama\u00f1o: 14<br>2019-04-02", "Jajajajaja<br>Tama\u00f1o: 10<br>2019-04-02", "Jajajajajaajaj<br>Tama\u00f1o: 14<br>2019-04-02", "Jajajajajajajaja<br>Tama\u00f1o: 16<br>2019-04-02", "Jajajajajajaja<br>Tama\u00f1o: 14<br>2019-04-02", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-02", "Jajajajajaja<br>Tama\u00f1o: 12<br>2019-04-02", "Jajaja<br>Tama\u00f1o: 6<br>2019-04-02", "Jajajajaja<br>Tama\u00f1o: 10<br>2019-04-02", "Jajaja<br>Tama\u00f1o: 6<br>2019-04-02", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-03", "Jjajaja<br>Tama\u00f1o: 7<br>2019-04-05", "JAJAJAJAJAJAJA<br>Tama\u00f1o: 14<br>2019-04-05", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-05", "Jajaj<br>Tama\u00f1o: 5<br>2019-04-06", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-06", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-06", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-06", "Jajajajaja<br>Tama\u00f1o: 10<br>2019-04-06", "Jajjajaajjajaja<br>Tama\u00f1o: 15<br>2019-04-06", "JAAJAJA<br>Tama\u00f1o: 7<br>2019-04-06", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-08", "Jajajajajajaja<br>Tama\u00f1o: 14<br>2019-04-08", "Jjjajajaja<br>Tama\u00f1o: 10<br>2019-04-08", "Jajj<br>Tama\u00f1o: 4<br>2019-04-08", "Jajaja<br>Tama\u00f1o: 6<br>2019-04-08", "Jaja<br>Tama\u00f1o: 4<br>2019-04-08", "Jajaja<br>Tama\u00f1o: 6<br>2019-04-08", "JAJAJAJAAJAJAJAJAJAJAJAJAJAJAAAAJJAA<br>Tama\u00f1o: 36<br>2019-04-08", "Jajajaja<br>Tama\u00f1o: 8<br>2019-04-08", "jajaja<br>Tama\u00f1o: 6<br>2019-04-10", "jajajaja<br>Tama\u00f1o: 8<br>2019-04-10", "JAJAJAJAJAJ<br>Tama\u00f1o: 11<br>2019-04-10", "JAJAJAJAJJA<br>Tama\u00f1o: 1 ...

# %%
pio.write_html(fig, file='Plot2.html', auto_open=True)

# %%
print(f"Tamaño promedio de la risa de Teresa: {df[(df['type']=='RISA') & (df['user']=='Teresa')].text.str.len().mean():.1f} caracteres.")
print(f"Tamaño promedio de la risa de Viviana: {df[(df['type']=='RISA') & (df['user']=='Viviana')].text.str.len().mean():.1f} caracteres.")
# Out:
# Tamaño promedio de la risa de Teresa: 18.3 caracteres.
# Tamaño promedio de la risa de Viviana: 12.2 caracteres.

# %% [markdown]
# # Continuación Exploración Inicial

# %%
print("Número de mensajes por usuario: ")
df.user.value_counts()
# Out:
# Número de mensajes por usuario:
# Teresa     9025
# Viviana    6960
# Name: user, dtype: int64

# %%
print("Tipo de mensajes, por usuario:")
df[~df['type'].isin(['Document', 'Contact'])].groupby(["type", "user"]).size().reset_index(name="count")
# Out:
# Tipo de mensajes, por usuario:
#           type     user  count
# 0        Audio   Teresa    775
# 1        Audio  Viviana    741
# 2  Image/Video   Teresa    375
# 3  Image/Video  Viviana    434
# 4         RISA   Teresa    570
# 5         RISA  Viviana    419
# 6  Sticker/GIF   Teresa    172
# 7  Sticker/GIF  Viviana    205
# 8         Text   Teresa   7132
# 9         Text  Viviana   5155

# %%
print("Mensajes más comunes de Teresa:")
df[(df['type']=='Text') & (df['user']=='Teresa')]['text'].value_counts().reset_index().head(16)
# Out:
# Mensajes más comunes de Teresa:
#            index  text
# 0          Amiga    85
# 1           Vivi    61
# 2          O sea    39
# 3              ?    28
# 4             Si    16
# 5         Marica    16
# 6      Epic fail    14
# 7          Parce    14
# 8             No    14
# 9          Listo    12
# 10           Wtf    12
# 11  🤦🏽‍♀🤦🏽‍♀🤦🏽‍♀    11
# 12          Fuck    10
# 13          Hola    10
# 14    Hola amiga    10
# 15      En serio    10

# %%
print("Mensajes más comunes de Viviana:")
df[(df['type']=='Text') & (df['user']=='Viviana')]['text'].value_counts().reset_index().head(16)
# Out:
# Mensajes más comunes de Viviana:
#                index  text
# 0                 Si    30
# 1              Amiga    28
# 2                 No    16
# 3          Epic fail    15
# 4                Oye    12
# 5          Demasiado     9
# 6              No se     9
# 7                  😭     8
# 8   Y tu cómo estás?     7
# 9         Hola amiga     7
# 10                X2     7
# 11                ❤️     6
# 12     Gracias amiga     6
# 13              Tere     6
# 14            Exacto     6
# 15        Yo también     6

# %% [markdown]
# # Volumen de interacciones por fecha

# %%
df['date'] = df['datetime'].apply(lambda date: date.date())

# %%
traces = []

# Total
trace_tere = go.Scatter(
                    x=df[df['user']=='Teresa'].groupby('date').count()['text'].reset_index().date.values,
                    y=df[df['user']=='Teresa'].groupby('date').count()['text'].reset_index().text.values,
                    text=[f"Teresa - Total<br>{val} mensajes<br>{date}" for val, date in \
                          zip(df[df['user']=='Teresa'].groupby('date').count()['text'].reset_index().text.values, \
                              df[df['user']=='Teresa'].groupby('date').count()['text'].reset_index().date.values)],
                    mode='lines', 
                    hoverinfo='text',
                    line = {
                        'color': color_tere,
                        'width': 1.2
                    },
                    name="Teresa"
                ) 

trace_vivi = go.Scatter(
                    x=df[df['user']=='Viviana'].groupby('date').count()['text'].reset_index().date.values,
                    y=df[df['user']=='Viviana'].groupby('date').count()['text'].reset_index().text.values,
                    text=[f"Viviana - Total<br>{val} mensajes<br>{date}" for val, date in \
                          zip(df[df['user']=='Viviana'].groupby('date').count()['text'].reset_index().text.values, \
                              df[df['user']=='Viviana'].groupby('date').count()['text'].reset_index().date.values)],
                    mode='lines',
                    hoverinfo='text',
                    line = {
                        'color': color_vivi,
                        'width': 1.2
                    },
                    name="Viviana"
                ) 

traces.append(trace_tere)
traces.append(trace_vivi)

# By category
for typ in df.type.unique()[:-2]:
    trace_tere = go.Scatter(
                        x=df[(df['user']=='Teresa') & (df['type']==typ)].groupby('date').count()['text'].reset_index().date.values,
                        y=df[(df['user']=='Teresa') & (df['type']==typ)].groupby('date').count()['text'].reset_index().text.values,
                        text=[f"Teresa - {typ}<br>{val} mensajes<br>{date}" for val, date in \
                              zip(df[(df['user']=='Teresa') & (df['type']==typ)].groupby('date').count()['text'].reset_index().text.values, \
                                  df[(df['user']=='Teresa') & (df['type']==typ)].groupby('date').count()['text'].reset_index().date.values)],
                        mode='lines', 
                        hoverinfo='text',
                        line = {
                            'color': color_tere,
                            'width': 1.2
                        },
                        name="Teresa",
                        visible=False
                    ) 

    trace_vivi = go.Scatter(
                        x=df[(df['user']=='Viviana') & (df['type']==typ)].groupby('date').count()['text'].reset_index().date.values,
                        y=df[(df['user']=='Viviana') & (df['type']==typ)].groupby('date').count()['text'].reset_index().text.values,
                        text=[f"Viviana - {typ}<br>{val} mensajes<br>{date})" for val, date in \
                              zip(df[(df['user']=='Viviana') & (df['type']==typ)].groupby('date').count()['text'].reset_index().text.values, \
                                  df[(df['user']=='Viviana') & (df['type']==typ)].groupby('date').count()['text'].reset_index().date.values)],
                        mode='lines',
                        hoverinfo='text',
                        line = {
                            'color': color_vivi,
                            'width': 1.2
                        },
                        name="Viviana",
                        visible=False
                    ) 
    
    traces.append(trace_tere)
    traces.append(trace_vivi)

# %%
updatemenus = list([
    dict(
         active=0,
         buttons=list([
            dict(label = 'Total',
                 method = 'restyle',
                 args = [{'visible': [
                                         True,
                                         True,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False]},
                         {'title': '¿Cuántos mensajes al día?<br>Total'}]),
             dict(label = 'Texto',
                 method = 'restyle',
                 args = [{'visible': [
                                         False,
                                         False,
                                         True,
                                         True,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False]},
                         {'title': '¿Cuántos mensajes al día?<br>Texto'}]),
             dict(label = 'RISA',
                 method = 'restyle',
                 args = [{'visible': [
                                         False,
                                         False,
                                         False,
                                         False,
                                         True,
                                         True,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False]},
                         {'title': '¿Cuántos mensajes al día?<br>RISA'}]),
             dict(label = 'Image/Video',
                 method = 'restyle',
                 args = [{'visible': [
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         True,
                                         True,
                                         False,
                                         False,
                                         False,
                                         False]},
                         {'title': '¿Cuántos mensajes al día?<br>Image/Video'}]),
             dict(label = 'Audio',
                 method = 'restyle',
                 args = [{'visible': [
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         True,
                                         True,
                                         False,
                                         False]},
                         {'title': '¿Cuántos mensajes al día?<br>Audio'}]),
             dict(label = 'Sticker/GIF',
                 method = 'restyle',
                 args = [{'visible': [
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         False,
                                         True,
                                         True]},
                         {'title': '¿Cuántos mensajes al día?<br>Sticker/GIF'}]),
        ]),
    )
])

# %%
layout = go.Layout(title="¿Cuántos mensajes al día?",
                   yaxis=dict(title='Número de mensajes',
                              #range=[0,500]
                             ),
                   xaxis=dict(range=[df.date.min(), df.date.max()]),
                   updatemenus=updatemenus
                  )

fig = go.Figure(data=traces, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="e77c7c9b-9396-4c5a-be00-6207a23739cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e77c7c9b-9396-4c5a-be00-6207a23739cd")) {
#                     Plotly.newPlot(
#                         'e77c7c9b-9396-4c5a-be00-6207a23739cd',
#                         [{"hoverinfo": "text", "line": {"color": "#33b2cb", "width": 1.2}, "mode": "lines", "name": "Teresa", "text": ["Teresa - Total<br>9 mensajes<br>2019-02-20", "Teresa - Total<br>124 mensajes<br>2019-02-26", "Teresa - Total<br>13 mensajes<br>2019-02-27", "Teresa - Total<br>4 mensajes<br>2019-03-01", "Teresa - Total<br>3 mensajes<br>2019-03-02", "Teresa - Total<br>47 mensajes<br>2019-03-04", "Teresa - Total<br>1 mensajes<br>2019-03-05", "Teresa - Total<br>30 mensajes<br>2019-03-06", "Teresa - Total<br>6 mensajes<br>2019-03-07", "Teresa - Total<br>91 mensajes<br>2019-03-08", "Teresa - Total<br>65 mensajes<br>2019-03-09", "Teresa - Total<br>13 mensajes<br>2019-03-10", "Teresa - Total<br>5 mensajes<br>2019-03-12", "Teresa - Total<br>3 mensajes<br>2019-03-13", "Teresa - Total<br>31 mensajes<br>2019-03-15", "Teresa - Total<br>16 mensajes<br>2019-03-16", "Teresa - Total<br>4 mensajes<br>2019-03-17", "Teresa - Total<br>99 mensajes<br>2019-03-18", "Teresa - Total<br>34 mensajes<br>2019-03-19", "Teresa - Total<br>1 mensajes<br>2019-03-21", "Teresa - Total<br>4 mensajes<br>2019-03-22", "Teresa - Total<br>3 mensajes<br>2019-03-28", "Teresa - Total<br>22 mensajes<br>2019-03-29", "Teresa - Total<br>74 mensajes<br>2019-03-30", "Teresa - Total<br>18 mensajes<br>2019-04-01", "Teresa - Total<br>198 mensajes<br>2019-04-02", "Teresa - Total<br>14 mensajes<br>2019-04-03", "Teresa - Total<br>30 mensajes<br>2019-04-04", "Teresa - Total<br>54 mensajes<br>2019-04-05", "Teresa - Total<br>71 mensajes<br>2019-04-06", "Teresa - Total<br>47 mensajes<br>2019-04-07", "Teresa - Total<br>116 mensajes<br>2019-04-08", "Teresa - Total<br>25 mensajes<br>2019-04-09", "Teresa - Total<br>41 mensajes<br>2019-04-10", "Teresa - Total<br>19 mensajes<br>2019-04-11", "Teresa - Total<br>1 mensajes<br>2019-04-12", "Teresa - Total<br>20 mensajes<br>2019-04-13", "Teresa - Total<br>10 mensajes<br>2019-04-14", "Teresa - Total<br>64 mensajes<br>2019-04-15", "Teresa - Total<br>16 mensajes<br>2019-04-16", "Teresa - Total<br>5 mensajes<br>2019-04-17", "Teresa - Total<br>257 mensajes<br>2019-04-18", "Teresa - Total<br>120 mensajes<br>2019-04-19", "Teresa - Total<br>117 mensajes<br>2019-04-20", "Teresa - Total<br>142 mensajes<br>2019-04-21", "Teresa - Total<br>88 mensajes<br>2019-04-22", "Teresa - Total<br>3 mensajes<br>2019-04-23", "Teresa - Total<br>42 mensajes<br>2019-04-24", "Teresa - Total<br>60 mensajes<br>2019-04-25", "Teresa - Total<br>11 mensajes<br>2019-04-26", "Teresa - Total<br>2 mensajes<br>2019-04-28", "Teresa - Total<br>68 mensajes<br>2019-04-29", "Teresa - Total<br>7 mensajes<br>2019-04-30", "Teresa - Total<br>15 mensajes<br>2019-05-01", "Teresa - Total<br>3 mensajes<br>2019-05-02", "Teresa - Total<br>5 mensajes<br>2019-05-07", "Teresa - Total<br>9 mensajes<br>2019-05-09", "Teresa - Total<br>132 mensajes<br>2019-05-12", "Teresa - Total<br>13 mensajes<br>2019-05-13", "Teresa - Total<br>1 mensajes<br>2019-05-15", "Teresa - Total<br>94 mensajes<br>2019-05-16", "Teresa - Total<br>72 mensajes<br>2019-05-21", "Teresa - Total<br>106 mensajes<br>2019-05-24", "Teresa - Total<br>20 mensajes<br>2019-05-25", "Teresa - Total<br>54 mensajes<br>2019-05-26", "Teresa - Total<br>4 mensajes<br>2019-05-27", "Teresa - Total<br>46 mensajes<br>2019-05-28", "Teresa - Total<br>5 mensajes<br>2019-05-30", "Teresa - Total<br>67 mensajes<br>2019-06-01", "Teresa - Total<br>4 mensajes<br>2019-06-03", "Teresa - Total<br>137 mensajes<br>2019-06-04", "Teresa - Total<br>60 mensajes<br>2019-06-05", "Teresa - Total<br>21 mensajes<br>2019-06-06", "Teresa - Total<br>101 mensajes<br>2019-06-07", "Teresa - Total<br>10 mensajes<br>2019-06-08", "Teresa - Total<br>2 mensajes<br>2019-06-09", "Teresa - Total<br>158 mensajes<br>2019-06-10", "Teresa - Total<br>24 mensajes<br>2019-06-11", "Teresa - Total<br>3 mensajes<br>2019-06-12", "Teresa - Total<br>11 mensajes<br>2019-06-13", "Teresa - Total<br>14 mensajes<br>2019-06-14", "Teresa - Total<br>25 mensajes<br>2019-06-15", "Teresa - Total<br>26 me ...

# %%
pio.write_html(fig, file='Plot3.html', auto_open=True)

# %%
df['dow'] = df['date'].apply(lambda date: calendar.day_name[date.weekday()])

# %%
trace_tere = go.Bar(
                x=df[df['user']=='Teresa'].dow.value_counts(normalize=True).reset_index()['index'].values,
                y=df[df['user']=='Teresa'].dow.value_counts(normalize=True).reset_index()['dow'].values,
                text=[f"Teresa<br>{count*100:.0f}% mensajes son enviados los {day}" for (day,count) in 
                      zip(df[df['user']=='Teresa'].dow.value_counts(normalize=True).reset_index()['index'].values, 
                          df[df['user']=='Teresa'].dow.value_counts(normalize=True).reset_index()['dow'].values)],
                hoverinfo='text', 
                opacity=0.6,
                marker=dict(color=color_tere,
                            line=dict(color=color_tere_dark,width=1.5,)
                           ),
                name='Teresa',
                #width=.8
)

trace_vivi = go.Bar(
                x=df[df['user']=='Viviana'].dow.value_counts(normalize=True).reset_index()['index'].values,
                y=df[df['user']=='Viviana'].dow.value_counts(normalize=True).reset_index()['dow'].values,
                text=[f"Viviana<br>{count*100:.0f}% mensajes son enviados los {day}" for (day,count) in 
                      zip(df[df['user']=='Viviana'].dow.value_counts(normalize=True).reset_index()['index'].values, 
                          df[df['user']=='Viviana'].dow.value_counts(normalize=True).reset_index()['dow'].values)],
                hoverinfo='text', 
                opacity=0.6,
                marker=dict(color=color_vivi,
                            line=dict(color=color_vivi_dark,width=1.5,)
                           ),
                name='Viviana',
                #width=.8
)

layout = go.Layout(title='Mensajes',
                   xaxis=dict(categoryorder='array',
                              categoryarray=list(calendar.day_name)),
                   yaxis=dict(tickformat=',.0%'),
                  )

fig = go.Figure(data=[trace_tere, trace_vivi], layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="36d899fb-77cc-473b-82cd-c3b33d2079c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("36d899fb-77cc-473b-82cd-c3b33d2079c2")) {
#                     Plotly.newPlot(
#                         '36d899fb-77cc-473b-82cd-c3b33d2079c2',
#                         [{"hoverinfo": "text", "marker": {"color": "#33b2cb", "line": {"color": "#237C8E", "width": 1.5}}, "name": "Teresa", "opacity": 0.6, "text": ["Teresa<br>21% mensajes son enviados los lunes", "Teresa<br>17% mensajes son enviados los martes", "Teresa<br>14% mensajes son enviados los s\u00e1bado", "Teresa<br>14% mensajes son enviados los viernes", "Teresa<br>13% mensajes son enviados los jueves", "Teresa<br>12% mensajes son enviados los domingo", "Teresa<br>9% mensajes son enviados los mi\u00e9rcoles"], "type": "bar", "x": ["lunes", "martes", "s\u00e1bado", "viernes", "jueves", "domingo", "mi\u00e9rcoles"], "y": [0.20587257617728533, 0.17307479224376732, 0.14282548476454293, 0.13617728531855955, 0.13340720221606647, 0.11722991689750692, 0.09141274238227147]}, {"hoverinfo": "text", "marker": {"color": "#db70c9", "line": {"color": "#994e8c", "width": 1.5}}, "name": "Viviana", "opacity": 0.6, "text": ["Viviana<br>18% mensajes son enviados los lunes", "Viviana<br>16% mensajes son enviados los martes", "Viviana<br>15% mensajes son enviados los s\u00e1bado", "Viviana<br>14% mensajes son enviados los jueves", "Viviana<br>14% mensajes son enviados los viernes", "Viviana<br>13% mensajes son enviados los domingo", "Viviana<br>11% mensajes son enviados los mi\u00e9rcoles"], "type": "bar", "x": ["lunes", "martes", "s\u00e1bado", "jueves", "viernes", "domingo", "mi\u00e9rcoles"], "y": [0.17586206896551723, 0.1610632183908046, 0.1485632183908046, 0.14382183908045976, 0.13591954022988506, 0.12600574712643678, 0.10876436781609196]}],
#                         {"template": {"data": {"scatter": [{"type": "scatter"}]}}, "title": {"text": "Mensajes"}, "xaxis": {"categoryarray": ["lunes", "martes", "mi\u00e9rcoles", "jueves", "viernes", "s\u00e1bado", "domingo"], "categoryorder": "array"}, "yaxis": {"tickformat": ",.0%"}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('36d899fb-77cc-473b-82cd-c3b33d2079c2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
pio.write_html(fig, file='Plot4.html', auto_open=True)

# %%
df['time'] = df['datetime'].apply(lambda date: str(date.time().replace(second=0)).rsplit(":",1)[0])

# %%
temp = df[['user', 'time']]
temp_tere = temp[temp['user']=='Teresa']['time'].value_counts(normalize=True).reset_index()
temp_vivi = temp[temp['user']=='Viviana']['time'].value_counts(normalize=True).reset_index()


minutes = [str(minute).zfill(2) for minute in range(0,60)]
hours = [str(hour).zfill(2) for hour in range(0,24)]
mins_hrs = [f"{minute}:{hour}" for minute in hours for hour in minutes]

for mh in mins_hrs:
    if temp_tere[(temp_tere['index']==mh)].shape[0] == 0:
        tempie = pd.DataFrame([[mh, 0]], columns = ['index', 'time'])
        temp_tere = pd.concat([temp_tere, tempie], ignore_index=True)
    
    if temp_vivi[(temp_vivi['index']==mh)].shape[0] == 0:
        tempie = pd.DataFrame([[mh, 0]], columns = ['index', 'time'])
        temp_vivi = pd.concat([temp_vivi, tempie], ignore_index=True)
        
temp_tere.sort_values('index', inplace=True)
temp_vivi.sort_values('index', inplace=True)

# %%
trace_tere = go.Scatter(
                    x=temp_tere['index'].values,
                    y=temp_tere['time'].values,
                    mode='lines', 
                    hoverinfo='text',
                    text=[f"Teresa<br>Hora: {time}<br>{count*100:.2f}% de los mensajes" for time,count in 
                         zip(temp_tere['index'].values, temp_tere['time'].values)],
                    line = {
                        'color': color_tere,
                        'width': 0.8
                    },
                    name="Teresa"
                ) 


trace_vivi = go.Scatter(
                    x=temp_vivi['index'].values,
                    y=temp_vivi['time'].values,
                    mode='lines', 
                    hoverinfo='text',
                    text=[f"Viviana<br>Hora: {time}<br>{count*100:.2f}% de los mensajes" for time,count in 
                         zip(temp_vivi['index'].values, temp_vivi['time'].values)],
                    line = {
                        'color': color_vivi,
                        'width': 0.8
                    },
                    name="Viviana"
                ) 


layout = go.Layout(title="¿A qué horas del día?",
                   yaxis=dict(tickformat=',.2%',
                              range=[0,0.0045]),
                   xaxis=dict(categoryorder='array',
                              categoryarray=mins_hrs,
                              tickmode = 'array',
                              tickvals=mins_hrs[::60])
                  )

fig = go.Figure(data=[trace_tere, trace_vivi], layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="44c772bc-8a9e-4bdb-907e-aa066ca9eda0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("44c772bc-8a9e-4bdb-907e-aa066ca9eda0")) {
#                     Plotly.newPlot(
#                         '44c772bc-8a9e-4bdb-907e-aa066ca9eda0',
#                         [{"hoverinfo": "text", "line": {"color": "#33b2cb", "width": 0.8}, "mode": "lines", "name": "Teresa", "text": ["Teresa<br>Hora: 00:00<br>0.07% de los mensajes", "Teresa<br>Hora: 00:01<br>0.07% de los mensajes", "Teresa<br>Hora: 00:02<br>0.06% de los mensajes", "Teresa<br>Hora: 00:03<br>0.07% de los mensajes", "Teresa<br>Hora: 00:04<br>0.06% de los mensajes", "Teresa<br>Hora: 00:05<br>0.08% de los mensajes", "Teresa<br>Hora: 00:06<br>0.04% de los mensajes", "Teresa<br>Hora: 00:07<br>0.00% de los mensajes", "Teresa<br>Hora: 00:08<br>0.06% de los mensajes", "Teresa<br>Hora: 00:09<br>0.02% de los mensajes", "Teresa<br>Hora: 00:10<br>0.04% de los mensajes", "Teresa<br>Hora: 00:11<br>0.01% de los mensajes", "Teresa<br>Hora: 00:12<br>0.07% de los mensajes", "Teresa<br>Hora: 00:13<br>0.02% de los mensajes", "Teresa<br>Hora: 00:14<br>0.00% de los mensajes", "Teresa<br>Hora: 00:15<br>0.01% de los mensajes", "Teresa<br>Hora: 00:16<br>0.00% de los mensajes", "Teresa<br>Hora: 00:17<br>0.00% de los mensajes", "Teresa<br>Hora: 00:18<br>0.02% de los mensajes", "Teresa<br>Hora: 00:19<br>0.04% de los mensajes", "Teresa<br>Hora: 00:20<br>0.01% de los mensajes", "Teresa<br>Hora: 00:21<br>0.11% de los mensajes", "Teresa<br>Hora: 00:22<br>0.03% de los mensajes", "Teresa<br>Hora: 00:23<br>0.01% de los mensajes", "Teresa<br>Hora: 00:24<br>0.02% de los mensajes", "Teresa<br>Hora: 00:25<br>0.11% de los mensajes", "Teresa<br>Hora: 00:26<br>0.01% de los mensajes", "Teresa<br>Hora: 00:27<br>0.03% de los mensajes", "Teresa<br>Hora: 00:28<br>0.00% de los mensajes", "Teresa<br>Hora: 00:29<br>0.11% de los mensajes", "Teresa<br>Hora: 00:30<br>0.13% de los mensajes", "Teresa<br>Hora: 00:31<br>0.00% de los mensajes", "Teresa<br>Hora: 00:32<br>0.03% de los mensajes", "Teresa<br>Hora: 00:33<br>0.04% de los mensajes", "Teresa<br>Hora: 00:34<br>0.07% de los mensajes", "Teresa<br>Hora: 00:35<br>0.03% de los mensajes", "Teresa<br>Hora: 00:36<br>0.00% de los mensajes", "Teresa<br>Hora: 00:37<br>0.00% de los mensajes", "Teresa<br>Hora: 00:38<br>0.06% de los mensajes", "Teresa<br>Hora: 00:39<br>0.03% de los mensajes", "Teresa<br>Hora: 00:40<br>0.00% de los mensajes", "Teresa<br>Hora: 00:41<br>0.01% de los mensajes", "Teresa<br>Hora: 00:42<br>0.02% de los mensajes", "Teresa<br>Hora: 00:43<br>0.01% de los mensajes", "Teresa<br>Hora: 00:44<br>0.02% de los mensajes", "Teresa<br>Hora: 00:45<br>0.00% de los mensajes", "Teresa<br>Hora: 00:46<br>0.04% de los mensajes", "Teresa<br>Hora: 00:47<br>0.04% de los mensajes", "Teresa<br>Hora: 00:48<br>0.03% de los mensajes", "Teresa<br>Hora: 00:49<br>0.02% de los mensajes", "Teresa<br>Hora: 00:50<br>0.02% de los mensajes", "Teresa<br>Hora: 00:51<br>0.00% de los mensajes", "Teresa<br>Hora: 00:52<br>0.00% de los mensajes", "Teresa<br>Hora: 00:53<br>0.00% de los mensajes", "Teresa<br>Hora: 00:54<br>0.06% de los mensajes", "Teresa<br>Hora: 00:55<br>0.03% de los mensajes", "Teresa<br>Hora: 00:56<br>0.04% de los mensajes", "Teresa<br>Hora: 00:57<br>0.03% de los mensajes", "Teresa<br>Hora: 00:58<br>0.08% de los mensajes", "Teresa<br>Hora: 00:59<br>0.00% de los mensajes", "Teresa<br>Hora: 01:00<br>0.13% de los mensajes", "Teresa<br>Hora: 01:01<br>0.13% de los mensajes", "Teresa<br>Hora: 01:02<br>0.04% de los mensajes", "Teresa<br>Hora: 01:03<br>0.01% de los mensajes", "Teresa<br>Hora: 01:04<br>0.01% de los mensajes", "Teresa<br>Hora: 01:05<br>0.04% de los mensajes", "Teresa<br>Hora: 01:06<br>0.01% de los mensajes", "Teresa<br>Hora: 01:07<br>0.03% de los mensajes", "Teresa<br>Hora: 01:08<br>0.00% de los mensajes", "Teresa<br>Hora: 01:09<br>0.01% de los mensajes", "Teresa<br>Hora: 01:10<br>0.01% de los mensajes", "Teresa<br>Hora: 01:11<br>0.01% de los mensajes", "Teresa<br>Hora: 01:12<br>0.00% de los mensajes", "Teresa<br>Hora: 01:13<br>0.02% de los mensajes", "Teresa<br>Hora: 01:14<br>0.00% de los mensajes", "Teresa<br>Hora: 01:15<br>0.04% de los mensajes", "Teresa<br>Hora: 01:16<br>0.01% de los mensajes", "Teresa<br>Hora ...

# %%
pio.write_html(fig, file='Plot4.html', auto_open=True)

# %% [markdown]
# # NPL

# %%
stop_words = get_stop_words('spanish')
regex_remove_punct = "([^\p{L}0-9']+)"

# %%
text_tere = df[(df['user']=='Teresa') & (df['type']=='Text')].text.str.cat(sep=' ')
text_vivi = df[(df['user']=='Viviana') & (df['type']=='Text')].text.str.cat(sep=' ')

# %%
print(f"Caracteres Teresa: {len(text_tere):,.0f}")
print(f"Caracteres Viviana: {len(text_vivi):,.0f}")
# Out:
# Caracteres Teresa: 164,350
# Caracteres Viviana: 198,810

# %%
text_tere_clean = regex.sub(regex_remove_punct, ' ',text_tere).lower().split()
text_tere_clean = [word for word in text_tere_clean if word not in stop_words]
print(f"Número de diferentes palabras Teresa: {len(set(text_tere_clean)):,.0f}")
Counter(text_tere_clean).most_common(20)
# Out:
# Número de diferentes palabras Teresa: 4,796
# [('amiga', 193),
#  ('vivi', 121),
#  ('voy', 89),
#  ('cómo', 86),
#  ('quiero', 76),
#  ('creo', 76),
#  ('serio', 75),
#  ('ay', 72),
#  ('vida', 68),
#  ('risa', 65),
#  ('re', 65),
#  ('dios', 64),
#  ('tan', 63),
#  ('así', 62),
#  ('foto', 61),
#  ('ahora', 60),
#  ('bueno', 59),
#  ('puedo', 59),
#  ('gusta', 57),
#  ('bien', 57)]

# %%
text_vivi_clean = regex.sub(regex_remove_punct, ' ',text_vivi).lower().split()
text_vivi_clean = [word for word in text_vivi_clean if word not in stop_words]
print(f"Número de diferentes palabras Viviana: {len(set(text_vivi_clean)):,.0f}")
Counter(text_vivi_clean).most_common(20)
# Out:
# Número de diferentes palabras Viviana: 4,847
# [('amiga', 356),
#  ('jajaja', 232),
#  ('jajajaja', 174),
#  ('re', 153),
#  ('literal', 125),
#  ('mk', 122),
#  ('creo', 107),
#  ('demasiado', 103),
#  ('quiero', 101),
#  ('así', 96),
#  ('bien', 92),
#  ('voy', 90),
#  ('jajajajaja', 89),
#  ('vida', 86),
#  ('siento', 85),
#  ('foto', 82),
#  ('vez', 81),
#  ('tan', 79),
#  ('amo', 77),
#  ('día', 75)]

# %% [markdown]
# #### Nombres

# %% [markdown]
# ```python
# for c in Counter(text_tere_clean).most_common():
#     if list(pp.tag(c[0])[0])==['GivenName'] and not d.check(c[0]) and len(set(c[0])) != 2:
#         if not d2.check(c[0]):
#             print(c)
#
# for c in Counter(text_vivi_clean).most_common():
#     if list(pp.tag(c[0])[0])==['GivenName'] and not d.check(c[0]) and len(set(c[0])) != 2:
#         if not d2.check(c[0]):
#             print(c)
# ```

# %%
### The following code is to weight words depending its frequency within the sentences from a linguistic perspective.
# Code from https://github.com/amueller/word_cloud/blob/master/wordcloud/tokenization.py
# Read more at http://nlp.stanford.edu/fsnlp/promo/colloc.pdf (dunning's likelihood ratio)

def pairwise(iterable):
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)


def score(count_bigram, count1, count2, n_words):
    if n_words <= count1 or n_words <= count2:
        return 0
    N = n_words
    c12 = count_bigram
    c1 = count1
    c2 = count2
    p = c2 / N
    p1 = c12 / c1
    p2 = (c2 - c12) / (N - c1)
    score = (l(c12, c1, p) + l(c2 - c12, N - c1, p)
             - l(c12, c1, p1) - l(c2 - c12, N - c1, p2))
    return -2 * score


def l(k, n, x):
    return log(max(x, 1e-10)) * k + log(max(1 - x, 1e-10)) * (n - k)


def process_tokens(words, normalize_plurals=True):
    d = defaultdict(dict)
    for word in words:
        word_lower = word.lower()
        case_dict = d[word_lower]
        case_dict[word] = case_dict.get(word, 0) + 1
    if normalize_plurals:
        merged_plurals = {}
        for key in list(d.keys()):
            if key.endswith('s') and not key.endswith("ss"):
                key_singular = key[:-1]
                if key_singular in d:
                    dict_plural = d[key]
                    dict_singular = d[key_singular]
                    for word, count in dict_plural.items():
                        singular = word[:-1]
                        dict_singular[singular] = (
                            dict_singular.get(singular, 0) + count)
                    merged_plurals[key] = key_singular
                    del d[key]
    fused_cases = {}
    standard_cases = {}
    item1 = itemgetter(1)
    for word_lower, case_dict in d.items():
        first = max(case_dict.items(), key=item1)[0]
        fused_cases[first] = sum(case_dict.values())
        standard_cases[word_lower] = first
    if normalize_plurals:
        for plural, singular in merged_plurals.items():
            standard_cases[plural] = standard_cases[singular.lower()]
    return fused_cases, standard_cases


def unigrams_and_bigrams(words, normalize_plurals=True):
    n_words = len(words)
    bigrams = list(pairwise(words))
    counts_unigrams, standard_form = process_tokens(words, normalize_plurals=normalize_plurals)
    counts_bigrams, standard_form_bigrams = process_tokens([" ".join(bigram) for bigram in bigrams],
                                                           normalize_plurals=normalize_plurals)
    counts = counts_unigrams.copy()

    for bigram_string, count in counts_bigrams.items():
        bigram = tuple(bigram_string.split(" "))
        word1 = standard_form[bigram[0].lower()]
        word2 = standard_form[bigram[1].lower()]

        if score(count, counts[word1], counts[word2], n_words) > 30:
            counts_unigrams[word1] -= counts_bigrams[bigram_string]
            counts_unigrams[word2] -= counts_bigrams[bigram_string]
            counts_unigrams[bigram_string] = counts_bigrams[bigram_string]
            
    words = list(counts_unigrams.keys())
    for word in words:
        if counts_unigrams[word] <= 0:
            del counts_unigrams[word]
    return counts_unigrams


def get_word_cloud(text, cat):

    stopwords = stop_words

    flags = (re.UNICODE if sys.version < '3' and type(text) is unicode else 0)
    regexp = r"\w[\w']+"

    words = re.findall(regexp, text, flags)
    words = [word for word in words if word.lower() not in stopwords]
    words = [word[:-2] if word.lower().endswith("'s") else word for word in words]
    words = [word for word in words if not word.isdigit()]
    words = [word for word in words if len(word) >= 0]
    
    df = pd.DataFrame(sorted(unigrams_and_bigrams(words, True).items(), key=lambda x: x[1], reverse=True))
    df.columns = ['word', 'count']
    df['type'] = cat
    return df

# %%
wc = pd.concat([get_word_cloud(text_tere, 'Teresa'),get_word_cloud(text_vivi, 'Viviana')])

# %%
wc.to_csv("wcTere.csv")

# %% [markdown]
# # Emojis

# %%
def get_emojis(text):
    emoji_list = []
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI for char in word):
            emoji_list.append(word)

    return emoji_list

# %%
emojis_tere = get_emojis(text_tere)
emojis_tere = pd.DataFrame(Counter(emojis_tere).most_common(), columns =['emoji', 'count'])

# %%
emojis_vivi = get_emojis(text_vivi)
emojis_vivi = pd.DataFrame(Counter(emojis_vivi).most_common(), columns =['emoji', 'count'])

# %%
print("Teresa")
print(f"Diferentes emojis usados: {emojis_tere.shape[0]}")
print(f"Número de emojis usados: {emojis_tere['count'].sum():,.0f}")

print("\nViviana")
print(f"Diferentes emojis usados: {emojis_vivi.shape[0]}")
print(f"Número de emojis usados: {emojis_vivi['count'].sum():,.0f}")
# Out:
# Teresa
# Diferentes emojis usados: 86
# Número de emojis usados: 1,023
#
# Viviana
# Diferentes emojis usados: 75
# Número de emojis usados: 645

# %%
print("Teresa")
print(f"Otros emojis: {emojis_tere.shape[0]-emojis_tere[~mask_tere].shape[0]}")
mask_tere = emojis_tere['count'] < threshold
for e in emojis_tere[mask_tere]['emoji'].values:
    print(e, end=" ")

print(end="\n\n")

for e in emojis_tere[~mask_tere]['emoji'].values:
    print(e, end=" ")
    
    
print(end="\n\n")

print("Viviana")
print(f"Otros emojis: {emojis_vivi.shape[0]-emojis_vivi[~mask_vivi].shape[0]}")
mask_vivi = emojis_vivi['count'] < threshold
for e in emojis_vivi[mask_vivi]['emoji'].values:
    print(e, end=" ")

print(end="\n\n")

for e in emojis_vivi[~mask_vivi]['emoji'].values:
    print(e, end=" ")
    
emojis_tere['user'] = 'Teresa'
emojis_vivi['user'] = 'Viviana'
pd.concat([emojis_tere,emojis_vivi]).to_csv("emojisTereALL.csv")
# Out:
# Teresa
# Otros emojis: 68
# 👌🏽 🤤 ⁉️ 😕 😶 🎉 😛 ❌ 😑 😁 👎🏽 🌈 💵 ✅ 🥺 😟 😘 🙌🏽 💫 🙃 💸 💴 🥳 🤩 💜 🏳‍🌈 😊 💁🏼 🙈 💷 🙄 🥴 😮 💁🏻 😇 💩 🏳 🧯 🏃🏽‍♀ 👾 ⚔ 🗡 🔪 😳 💛 💶 😏 🍆 😐 👏🏽 🥶 🥵 💪🏽 💁🏽 👉🏽 😪 💗 🙊 💚 💁🏽‍♀ 😄 🤙🏽 🤘🏽 👩🏼‍🎤 👩🏼‍🔬 🤰🏼 🤱🏼 😫
#
# ❤ 🤦🏽‍♀ 😱 😭 😍 💔 🧠 ☹️ 🔥 😡 💘 🙏🏽 🤞🏽 💓 🖕🏽 💖 💞 👍🏽
#
# Viviana
# Otros emojis: 58
# 😢 ♥️ 👀 🔫 👍 💜 😔 🐘 👏 🥰 ❌ 🤗 💁‍♀️ 😨 🎉 💩 🍑 😞 🍁 🥵 ✅ 🤪 😁 🐬 🙈 🏳️ 🌈 😤 🙁 💯 ✂️ 😰 🌹 💐 🌷 👙 🍻 💦 💧 🚿 🍺 😃 🥚 😮 😿 💉 😕 🤷‍♀️ 🌳 👎 😻 🍷 🕯 😉 🤒 🦟 😆 😩
#
# 😭 ❤️ ☹️ 💔 😂 😍 🤦‍♀️ 😱 😡 🤣 👌 💕 🥺 😏 🤞 😬 🙏

# %%
threshold = 10

emojis_tere = get_emojis(text_tere)
emojis_tere = pd.DataFrame(Counter(emojis_tere).most_common(), columns =['emoji', 'count'])
mask = emojis_tere['count'] < threshold
n_mask = emojis_tere[~mask]
tempie = pd.DataFrame([["Others", emojis_tere[mask]['count'].sum()]], columns = emojis_tere.columns)
emojis_tere = pd.concat([n_mask, tempie], ignore_index=True)
emojis_tere['user'] = 'Teresa'

emojis_vivi = get_emojis(text_vivi)
emojis_vivi = pd.DataFrame(Counter(emojis_vivi).most_common(), columns =['emoji', 'count'])
mask = emojis_vivi['count'] < threshold
n_mask = emojis_vivi[~mask]
tempie = pd.DataFrame([["Others", emojis_vivi[mask]['count'].sum()]], columns = emojis_vivi.columns)
emojis_vivi= pd.concat([n_mask, tempie], ignore_index=True)
emojis_vivi['user'] = 'Viviana'

df_emojis = pd.concat([emojis_tere, emojis_vivi], ignore_index=True)
df_emojis['emojis'] = 'Emojis'

# %%
fig = px.treemap(df_emojis, 
                 path=['emojis', 'user', 'emoji'], 
                 values='count',
                 color='user',
                 color_discrete_map={'(?)': "light_gray", 
                                     'Teresa': color_tere, 
                                     'Viviana': color_vivi},
                hover_name="user")
fig.show()
# Out:
# <div>
#
#
#             <div id="9a773dbd-84c8-40b7-877f-1bf5a4994e08" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9a773dbd-84c8-40b7-877f-1bf5a4994e08")) {
#                     Plotly.newPlot(
#                         '9a773dbd-84c8-40b7-877f-1bf5a4994e08',
#                         [{"branchvalues": "total", "customdata": [["Teresa"], ["Viviana"], ["Teresa"], ["Teresa"], ["Teresa"], ["Teresa"], ["Teresa"], ["Viviana"], ["Viviana"], ["Teresa"], ["Teresa"], ["Teresa"], ["Viviana"], ["Viviana"], ["Teresa"], ["Viviana"], ["Teresa"], ["Viviana"], ["Teresa"], ["Teresa"], ["Viviana"], ["Teresa"], ["Viviana"], ["Viviana"], ["Viviana"], ["Teresa"], ["Viviana"], ["Viviana"], ["Viviana"], ["Teresa"], ["Viviana"], ["Teresa"], ["Viviana"], ["Viviana"], ["Viviana"], ["Teresa"], ["Teresa"], ["Teresa"], ["Viviana"], ["(?)"]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "<b>%{hovertext}</b><br><br>user=%{customdata[0]}<br>labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "hovertext": ["Teresa", "Viviana", "Teresa", "Teresa", "Teresa", "Teresa", "Teresa", "Viviana", "Viviana", "Teresa", "Teresa", "Teresa", "Viviana", "Viviana", "Teresa", "Viviana", "Teresa", "Viviana", "Teresa", "Teresa", "Viviana", "Teresa", "Viviana", "Viviana", "Viviana", "Teresa", "Viviana", "Viviana", "Viviana", "Teresa", "Viviana", "Teresa", "Viviana", "Viviana", "Viviana", "Teresa", "Teresa", "Teresa", "Viviana", "(?)"], "ids": ["Emojis/Teresa/Others", "Emojis/Viviana/\ud83d\ude02", "Emojis/Teresa/\ud83d\udd95\ud83c\udffd", "Emojis/Teresa/\ud83d\udd25", "Emojis/Teresa/\ud83d\udc9e", "Emojis/Teresa/\ud83d\udc98", "Emojis/Teresa/\ud83d\udc96", "Emojis/Viviana/\ud83d\udc95", "Emojis/Viviana/\ud83d\udc94", "Emojis/Teresa/\ud83d\ude0d", "Emojis/Teresa/\ud83d\udc93", "Emojis/Teresa/\ud83d\udc4d\ud83c\udffd", "Emojis/Viviana/\ud83d\udc4c", "Emojis/Viviana/\u2764\ufe0f", "Emojis/Teresa/\u2764", "Emojis/Viviana/\u2639\ufe0f", "Emojis/Teresa/\u2639\ufe0f", "Emojis/Viviana/Others", "Emojis/Teresa/\ud83d\udc94", "Emojis/Teresa/\ud83d\ude4f\ud83c\udffd", "Emojis/Viviana/\ud83e\udd1e", "Emojis/Teresa/\ud83e\udd26\ud83c\udffd\u200d\u2640", "Emojis/Viviana/\ud83e\udd23", "Emojis/Viviana/\ud83e\udd26\u200d\u2640\ufe0f", "Emojis/Viviana/\ud83d\ude4f", "Emojis/Teresa/\ud83e\udd1e\ud83c\udffd", "Emojis/Viviana/\ud83d\ude31", "Emojis/Viviana/\ud83d\ude2c", "Emojis/Viviana/\ud83d\ude2d", "Emojis/Teresa/\ud83d\ude2d", "Emojis/Viviana/\ud83d\ude21", "Emojis/Teresa/\ud83d\ude21", "Emojis/Viviana/\ud83d\ude0f", "Emojis/Viviana/\ud83d\ude0d", "Emojis/Viviana/\ud83e\udd7a", "Emojis/Teresa/\ud83d\ude31", "Emojis/Teresa/\ud83e\udde0", "Emojis/Teresa", "Emojis/Viviana", "Emojis"], "labels": ["Others", "\ud83d\ude02", "\ud83d\udd95\ud83c\udffd", "\ud83d\udd25", "\ud83d\udc9e", "\ud83d\udc98", "\ud83d\udc96", "\ud83d\udc95", "\ud83d\udc94", "\ud83d\ude0d", "\ud83d\udc93", "\ud83d\udc4d\ud83c\udffd", "\ud83d\udc4c", "\u2764\ufe0f", "\u2764", "\u2639\ufe0f", "\u2639\ufe0f", "Others", "\ud83d\udc94", "\ud83d\ude4f\ud83c\udffd", "\ud83e\udd1e", "\ud83e\udd26\ud83c\udffd\u200d\u2640", "\ud83e\udd23", "\ud83e\udd26\u200d\u2640\ufe0f", "\ud83d\ude4f", "\ud83e\udd1e\ud83c\udffd", "\ud83d\ude31", "\ud83d\ude2c", "\ud83d\ude2d", "\ud83d\ude2d", "\ud83d\ude21", "\ud83d\ude21", "\ud83d\ude0f", "\ud83d\ude0d", "\ud83e\udd7a", "\ud83d\ude31", "\ud83e\udde0", "Teresa", "Viviana", "Emojis"], "marker": {"colors": ["#33b2cb", "#db70c9", "#33b2cb", "#33b2cb", "#33b2cb", "#33b2cb", "#33b2cb", "#db70c9", "#db70c9", "#33b2cb", "#33b2cb", "#33b2cb", "#db70c9", "#db70c9", "#33b2cb", "#db70c9", "#33b2cb", "#db70c9", "#33b2cb", "#33b2cb", "#db70c9", "#33b2cb", "#db70c9", "#db70c9", "#db70c9", "#33b2cb", "#db70c9", "#db70c9", "#db70c9", "#33b2cb", "#db70c9", "#33b2cb", "#db70c9", "#db70c9", "#db70c9", "#33b2cb", "#33b2cb", "#33b2cb", "#db70c9", "light_gray"]}, "name": "", "parents": ["Emojis/Teresa", "Emojis/Viviana", "Emojis/Teresa", "Emojis/Teresa", "Emojis/Teresa", "Emojis/Teresa", "Emojis/Teresa", "Emojis/Viviana", "Emojis/Viviana", "Emojis/Teresa", "Emojis/Teresa", "Emojis/Teresa", "Emojis/Viviana", "Emojis/Viviana", "Emojis/Teresa", "Emojis/Viviana", "Emojis/Teresa", "Emojis/Viviana", "Emojis/Teresa", "Emojis/Teresa", "Emojis/ ...
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"scatter": [{"type": "scatter"}]}}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9a773dbd-84c8-40b7-877f-1bf5a4994e08');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
df_emojis.to_csv("emojisTere.csv")
